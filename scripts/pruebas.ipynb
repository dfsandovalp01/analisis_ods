# %%
from optimize_images import optimize_images

# %%
optimize_images(input_dir="../config/institucional/logos/institucional", max_size=(800, 800))
# Out:
# Optimizado: GOBIERNO-DE-COLOMBIA_HORIZONTAL.png -> GOBIERNO-DE-COLOMBIA_HORIZONTAL.webp
#   Reducción: 17.6KB -> 17.9KB
# Optimizado: LOGO MPTF (ESP).png -> LOGO MPTF (ESP).webp
#   Reducción: 226.6KB -> 57.5KB
